# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.pandas.set_option('display.max_columns', None)
# %matplotlib inline

# %%
data = pd.read_csv("bank-additional-full.csv")
data.head(10)
# Out:
#   age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"
# 0  56;"housemaid";"married";"basic.4y";"no";"no";...
# 1  57;"services";"married";"high.school";"unknown...
# 2  37;"services";"married";"high.school";"no";"ye...
# 3  40;"admin.";"married";"basic.6y";"no";"no";"no...
# 4  56;"services";"married";"high.school";"no";"no...
# 5  45;"services";"married";"basic.9y";"unknown";"...
# 6  59;"admin.";"married";"professional.course";"n...
# 7  41;"blue-collar";"married";"unknown";"unknown"...
# 8  24;"technician";"single";"professional.course"...
# 9  25;"services";"single";"high.school";"no";"yes...

# %%
data = pd.read_csv("bank-additional-full.csv", delimiter = ";")
data.head(10)
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  duration  campaign  pdays  previous  \
# 0  telephone   may         mon       261         1    999         0
# ...

# %%
data.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
data.duplicated().sum()
# Out:
# 12

# %%
data.drop_duplicates(inplace=True)

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380    258.315815      2.567879    962.464810      0.173013
# std       10.42068    259.305321      2.770318    186.937102      0.494964
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41176.000000    41176.000000   41176.000000  41176.000000  41176.000000
# mean       0.081922       93.575720     -40.502863      3.621293   5167.034870
# ...

# %%
for column in data.columns:
    print(data[column].nunique())
# Out:
# 78
# 12
# 4
# 8
# 3
# 3
# 3
# 2
# 10
# 5
# 1544
# 42
# 27
# 8
# 3
# 10
# 26
# 26
# 316
# 11
# 2

# %%
num_feat = []
for column in data.columns:
    if data[column].dtypes != "O":
        num_feat.append(column)
num_feat
# Out:
# ['age',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %%
discrete_var = []
for column in num_feat:
    if data[column].nunique() <= 15:
        discrete_var.append(column)
discrete_var
# Out:
# ['previous', 'emp.var.rate', 'nr.employed']

# %%
cat_feat = []
for column in data.columns:
    if column not in num_feat:
        cat_feat.append(column)
cat_feat
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome',
#  'y']

# %%
for feat in num_feat:
    df = data.copy()
    sns.histplot(data = df, x = feat, hue = df["y"], bins = 40)
    plt.show()

# %%
for feat in cat_feat:
    df = data.copy()
    plt.figure(figsize = (10, 8))
    sns.countplot(x = feat, data = data)
    plt.xlabel(feat)
    plt.ylabel("Count")
    plt.title(f"Countplot for {feat}")
    plt.show()

# %%
# Select only the numerical columns
numerical_df = data.select_dtypes(include=[np.number])

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
high_corr_cols = ['euribor3m','nr.employed']
data = data.drop(columns = high_corr_cols)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
label_encoder = LabelEncoder()
for i in cat_feat:
    data[i] = label_encoder.fit_transform(data[i])

# %%
data.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 1   57    7        1          3        1        0     0        1      6
# 2   37    7        1          3        0        2     0        1      6
# 3   40    0        1          1        0        0     0        1      6
# 4   56    7        1          3        0        0     2        1      6
#
#    day_of_week  duration  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1       261         1    999         0         1           1.1
# 1            1       149         1    999         0         1           1.1
# 2            1       226         1    999         0         1           1.1
# 3            1       151         1    999         0         1           1.1
# 4            1       307         1    999         0         1           1.1
#
#    cons.price.idx  cons.conf.idx  y
# 0          93.994          -36.4  0
# ...

# %%
scaler = StandardScaler()
X = data.drop(columns = ["y"], axis = 1)
y = df["y"]
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[ 1.53314313, -0.20147477, -0.28370335, ...,  0.64810117,
#          0.72262789,  0.88656813],
#        [ 1.62910732,  0.9113627 , -0.28370335, ...,  0.64810117,
#          0.72262789,  0.88656813],
#        [-0.29017656,  0.9113627 , -0.28370335, ...,  0.64810117,
#          0.72262789,  0.88656813],
#        ...,
#        [ 1.53314313,  0.35494396, -0.28370335, ..., -0.75240241,
#          2.05807592, -2.22505906],
#        [ 0.3815728 ,  1.46778143, -0.28370335, ..., -0.75240241,
#          2.05807592, -2.22505906],
#        [ 3.26049862,  0.35494396, -0.28370335, ..., -0.75240241,
#          2.05807592, -2.22505906]])

# %%
X_scaled = pd.DataFrame(X_scaled, columns = X.columns)
X_scaled.head()
# Out:
#         age       job   marital  education   default   housing     loan  \
# 0  1.533143 -0.201475 -0.283703  -1.753753 -0.513657 -1.087787 -0.45257
# 1  1.629107  0.911363 -0.283703  -0.349596  1.945111 -1.087787 -0.45257
# 2 -0.290177  0.911363 -0.283703  -0.349596 -0.513657  0.942065 -0.45257
# 3 -0.002284 -1.036103 -0.283703  -1.285700 -0.513657 -1.087787 -0.45257
# 4  1.533143  0.911363 -0.283703  -0.349596 -0.513657 -1.087787  2.31104
#
#     contact     month  day_of_week  duration  campaign     pdays  previous  \
# 0  1.318174  0.762504    -0.718775  0.010352 -0.565963  0.195443 -0.349551
# 1  1.318174  0.762504    -0.718775 -0.421577 -0.565963  0.195443 -0.349551
# 2  1.318174  0.762504    -0.718775 -0.124626 -0.565963  0.195443 -0.349551
# 3  1.318174  0.762504    -0.718775 -0.413864 -0.565963  0.195443 -0.349551
# 4  1.318174  0.762504    -0.718775  0.187751 -0.565963  0.195443 -0.349551
#
#    poutcome  emp.var.rate  cons.price.idx  cons.conf.idx
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, stratify = y, test_size = 0.3, random_state = 0)

# %%
from collections import Counter
print(Counter(y_train))
print(Counter(y_val))
# Out:
# Counter({'no': 25576, 'yes': 3247})
# Counter({'no': 10961, 'yes': 1392})

# %%
from sklearn.tree import DecisionTreeClassifier
error_rate = []
for i in range(1, 20):
    model = DecisionTreeClassifier(criterion = "gini", max_depth = i)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    error = np.mean(y_pred != y_val)
    error_rate.append(error)
error_rate
# Out:
# [0.11268517768963004,
#  0.09900429045575973,
#  0.09528049866429207,
#  0.09366145875495831,
#  0.09155670687282441,
#  0.09398526673682506,
#  0.09066623492269084,
#  0.09179956285922448,
#  0.09544240265522545,
#  0.09617097061442564,
#  0.0985185784829596,
#  0.10078523435602688,
#  0.10224237027442726,
#  0.10458997814296123,
#  0.10628997004776168,
#  0.11130899376669635,
#  0.11187565773496316,
#  0.11478992957176394,
#  0.11673277746296447]

# %%
plt.figure(figsize = (10, 8))
plt.plot(range(1, 20), error_rate, color = "blue", marker = "o")
plt.xlabel("Max_depth")
plt.ylabel("Error Rate")
plt.show()

# %%
error_ = []
for i in range(2, 20):
    model = DecisionTreeClassifier(criterion = "gini", max_depth = 7, min_samples_split=i)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    error = np.mean(y_pred != y_val)
    error_.append(error)
error_
# Out:
# [0.09066623492269084,
#  0.09066623492269084,
#  0.09066623492269084,
#  0.09058528292722416,
#  0.09058528292722416,
#  0.09058528292722416,
#  0.09058528292722416,
#  0.09058528292722416,
#  0.09058528292722416,
#  0.09050433093175747,
#  0.09050433093175747,
#  0.09050433093175747,
#  0.09050433093175747,
#  0.09050433093175747,
#  0.09050433093175747,
#  0.09050433093175747,
#  0.09050433093175747,
#  0.09050433093175747]

# %%
plt.figure(figsize = (10, 8))
plt.plot(range(2, 20), error_, color = "blue", marker = "o")
plt.xlabel("Max_depth")
plt.ylabel("Error Rate")
plt.show()

# %%
dtc = DecisionTreeClassifier(criterion = "gini", max_depth = 7, min_samples_split = 11)
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_split=11)

# %%
dtc_pred = dtc.predict(X_val)

# %%
print(dtc.score(X_train, y_train))
print(dtc.score(X_val, y_val))
# Out:
# 0.9227006210318148
# 0.9094956690682425

# %%
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score, confusion_matrix, classification_report
print(accuracy_score(y_pred, y_val))
# Out:
# 0.9094956690682425

# %%
print(confusion_matrix(y_val, y_pred))
# Out:
# [[10467   494]
#  [  624   768]]

# %%
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.94      0.95      0.95     10961
#          yes       0.61      0.55      0.58      1392
#
#     accuracy                           0.91     12353
#    macro avg       0.78      0.75      0.76     12353
# weighted avg       0.91      0.91      0.91     12353

# %%
from sklearn.tree import plot_tree
feature_names = data.columns.tolist()
plt.figure(figsize=(40,20))
class_names=["class_0","class_1"]
plot_tree(dtc, feature_names=feature_names, class_names=class_names, filled=True,fontsize=12)
plt.show()
